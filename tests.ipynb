# %%
from data_generator import GenerateStateDataset

# %%
data = GenerateStateDataset(num_samples = 200)
# Out:
# Generating 200 state samples (len 8-20)...
# Saved to data\state_dataset.npz (X: (200, 8), Y: (200, 64, 8))

# %%
data[0][0]
# Out:
# array([ 0.86221075,  0.7713017 ,  0.20260434,  0.38131097,  0.39482895,
#         0.45976272, -0.90643364,  0.55658746], dtype=float32)

# %%
data[0][1]
# Out:
# array([ 0.7870699 ,  0.07413712, -0.6491398 , -0.07444428,  0.7543836 ,
#         0.2633458 , -0.7398409 , -0.19618657], dtype=float32)
